# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
from scipy.interpolate import CubicSpline

# %%
x,y = np.loadtxt('vicsek40s.txt',delimiter='\t',unpack=True)

# %%
f = CubicSpline(x,y)
#f = np.poly1d(np.polyfit(x5, y5, 4))
xnew = np.linspace(0, 9.75, num=100, endpoint=True)
plt.plot(x, y, 'bo', xnew, f(xnew), 'b-')

# %%
x2,y2 = np.loadtxt('vicsek402s.txt',delimiter='\t',unpack=True)
f2 = CubicSpline(x2,y2)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x2, y2, 'bo', xnew, f2(xnew), 'b-')

# %%
x3,y3 = np.loadtxt('vicsek403s.txt',delimiter='\t',unpack=True)
f3 = CubicSpline(x3,y3)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x3, y3, 'bo', xnew, f3(xnew), 'b-')

# %%
x4,y4 = np.loadtxt('vicsek404s.txt',delimiter='\t',unpack=True)
f4 = CubicSpline(x4,y4)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x4, y4, 'bo', xnew, f4(xnew), 'b-')

# %%
x5,y5 = np.loadtxt('vicsek405s.txt',delimiter='\t',unpack=True)
f5 = CubicSpline(x5,y5)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x5, y5, 'bo', xnew, f5(xnew), 'b-')

# %%
x6,y6 = np.loadtxt('vicsek406s.txt',delimiter='\t',unpack=True)
f6 = CubicSpline(x6,y6)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x6, y6, 'bo', xnew, f6(xnew), 'b-')

# %%
x7,y7 = np.loadtxt('vicsek402_1s.txt',delimiter='\t',unpack=True)
f7 = CubicSpline(x7,y7)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x7, y7, 'bo', xnew, f7(xnew), 'b-')

# %%
x8,y8 = np.loadtxt('vicsek402_2s.txt',delimiter='\t',unpack=True)
f8 = CubicSpline(x8,y8)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x8, y8, 'bo', xnew, f8(xnew), 'b-')

# %%
x9,y9 = np.loadtxt('vicsek402_3s.txt',delimiter='\t',unpack=True)
f9 = CubicSpline(x9,y9)
xnew = np.linspace(3,5, num=100, endpoint=True)
plt.plot(x9, y9, 'bo', xnew, f9(xnew), 'b-')

# %%
x10,y10 = np.loadtxt('vicsek402_4s.txt',delimiter='\t',unpack=True)
f10 = CubicSpline(x10,y10)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x10, y10, 'bo', xnew, f10(xnew), 'b-')

# %%
x11,y11 = np.loadtxt('vicsek402_6s.txt',delimiter='\t',unpack=True)
f11 = CubicSpline(x11,y11)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x11, y11, 'bo', xnew, f11(xnew), 'b-')

# %%
x12,y12 = np.loadtxt('vicsek402_7s.txt',delimiter='\t',unpack=True)
f12 = CubicSpline(x12,y12)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x12, y12, 'bo', xnew, f12(xnew), 'b-')

# %%
x13,y13 = np.loadtxt('vicsek402_8s.txt',delimiter='\t',unpack=True)
f13 = CubicSpline(x13,y13)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x13, y13, 'bo', xnew, f13(xnew), 'b-')

# %%
x14,y14 = np.loadtxt('vicsek402_9s.txt',delimiter='\t',unpack=True)
f14 = CubicSpline(x14,y14)
xnew = np.linspace(3, 5, num=100, endpoint=True)
plt.plot(x14, y14, 'bo', xnew, f14(xnew), 'b-')

# %%
#plt.plot( xnew, f(xnew), '-',label='r=0')
plt.plot(xnew, f2(xnew), '-',label='r=0.1')
plt.plot(xnew, f3(xnew), '-',label='r=0.2')
plt.plot(xnew, f6(xnew), '-',label='r=0.25')
plt.plot(xnew, f7(xnew), '-',label='r=0.21')
plt.plot(xnew, f8(xnew), '-',label='r=0.22')
plt.plot(xnew, f9(xnew), '-',label='r=0.23')
plt.plot(xnew, f10(xnew), '-',label='r=0.24')
plt.plot(xnew, f11(xnew), '-',label='r=0.26')
plt.plot(xnew, f12(xnew), '-',label='r=0.27')
plt.plot(xnew, f13(xnew), '-',label='r=0.28')
plt.plot(xnew, f14(xnew), '-',label='r=0.29')
plt.plot(xnew, f4(xnew), '-',label='r=0.3')
plt.plot(xnew, f5(xnew), '-',label='r=0.5')
plt.legend()

# %%
eta_c = [xnew[np.argmax(f2(xnew))],xnew[np.argmax(f3(xnew))],
  xnew[np.argmax(f7(xnew))],
 xnew[np.argmax(f8(xnew))], xnew[np.argmax(f9(xnew))],
 xnew[np.argmax(f10(xnew))], xnew[np.argmax(f6(xnew))],
 xnew[np.argmax(f11(xnew))],
 xnew[np.argmax(f12(xnew))], xnew[np.argmax(f13(xnew))],
 xnew[np.argmax(f14(xnew))],
 xnew[np.argmax(f4(xnew))],xnew[np.argmax(f5(xnew))]]

# %%
r=[0.1,0.2,0.21,0.22,0.23,0.24,0.25,0.26,0.27,0.28,
  0.29,0.3,0.5]

# %%
from scipy.optimize import curve_fit

def sigmoid(x,a,b, x0, k):
     y = a + b / (1 + np.exp(-k*(x-x0)))
     return y

def tanhy(x,a,b,c,x0):
     y = a+c*np.tanh((x-x0)*b)
     return y

#xdata = np.array([0.0,   1.0,  3.0, 4.3, 7.0,   8.0,   8.5, 10.0, 12.0])
#ydata = np.array([0.01, 0.02, 0.04, 0.11, 0.43,  0.7, 0.89, 0.95, 0.99])

popt, pcov = curve_fit(tanhy, r, eta_c)
print popt


x= np.linspace(0.1, 0.5, num=100, endpoint=True)
y = tanhy(x, *popt)
plt.plot(r, eta_c, 'o', label='data')
plt.plot(x,y, label='fit')
# Out:
# [  3.99044169 -15.7397277   -0.48387105   0.22335956]

# %%
xtanh = np.linspace(-1, 1, num=100, endpoint=True)
plt.plot(xtanh,np.tanh(xtanh*3))

# %%
"""
==========================
Vicsek Model
==========================
"""

#!/usr/bin/env python

import numpy as np
from matplotlib import pyplot as plt
import cython
from matplotlib.widgets import Button
import sys

#Define Variables

v=1
eta=0.1
L=50
N=1000

#Initial State

def initialize():
    global x,y,theta,theta_new,order,order_new,order_inst
    x=np.random.uniform(0,L,N)
    y=np.random.uniform(0,L,N)
    theta=np.random.uniform(-np.pi,np.pi,N)
    theta_new=np.random.uniform(-np.pi,np.pi,N)
    order=0
    order_new=1
    order_inst=[]

#Functions
def dist(i,j):
    return np.sqrt((x[i]-x[j])**2+(y[i]-y[j])**2)

def update():
    for i in range(N):
        theta_near = []
        for j in range(N):
            if dist(i,j)<1:
                theta_near.append(theta[j])
        theta_new[i] = np.mean(theta_near)+eta*np.random.uniform(-np.pi,np.pi)
    for i in range(N):
        theta[i]=theta_new[i]
        x[i]=(x[i]+v*np.cos(theta[i]))%L
        y[i]=(y[i]+v*np.sin(theta[i]))%L


#Plot

initialize()

def reset(event):
    sys.exit()
    
n=100

for t in range(n):
    if t%1==0:
        axes = plt.gca();
        axes.set_xlim([0,L]);
        axes.set_ylim([0,L]);
        plt.quiver(x,y,np.cos(theta),np.sin(theta), units='width',scale=30,width=0.005,pivot='mid');
        plt.savefig('plots/picture'+str(t));
        #plt.pause(0.01);
        plt.gcf().clear();   
    update()

# %%
import subprocess
subprocess.call(['ffmpeg', '-i', 'picture%d0.png', 'output.avi'])
subprocess.call(['ffmpeg', '-i', 'output.avi', '-t', '5', 'out.gif'])
# Out:
# 1
