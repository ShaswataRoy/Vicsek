# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
from scipy.interpolate import CubicSpline

# %%
x,y = np.loadtxt('vicsek40s.txt',delimiter='\t',unpack=True)

# %%
f = CubicSpline(x,y)
#f = np.poly1d(np.polyfit(x5, y5, 4))
xnew = np.linspace(0, 9.75, num=100, endpoint=True)
plt.plot(x, y, 'bo', xnew, f(xnew), 'b-')

# %%
x2,y2 = np.loadtxt('vicsek402s.txt',delimiter='\t',unpack=True)
f2 = CubicSpline(x2,y2)
xnew = np.linspace(0, 6.3, num=100, endpoint=True)
plt.plot(x2, y2, 'bo', xnew, f2(xnew), 'b-')

# %%
x3,y3 = np.loadtxt('vicsek403s.txt',delimiter='\t',unpack=True)
f3 = CubicSpline(x3,y3)
xnew = np.linspace(0, 6.28, num=100, endpoint=True)
plt.plot(x3, y3, 'bo', xnew, f3(xnew), 'b-')

# %%
x4,y4 = np.loadtxt('vicsek404s.txt',delimiter='\t',unpack=True)
f4 = CubicSpline(x4,y4)
xnew = np.linspace(0, 6.28, num=100, endpoint=True)
plt.plot(x4, y4, 'bo', xnew, f4(xnew), 'b-')

# %%
x5,y5 = np.loadtxt('vicsek405s.txt',delimiter='\t',unpack=True)
f5 = CubicSpline(x5,y5)
xnew = np.linspace(0, 6.28, num=100, endpoint=True)
plt.plot(x5, y5, 'bo', xnew, f5(xnew), 'b-')

# %%
x6,y6 = np.loadtxt('vicsek406s.txt',delimiter='\t',unpack=True)
f6 = CubicSpline(x6,y6)
xnew = np.linspace(0, 6.15, num=100, endpoint=True)
plt.plot(x6, y6, 'bo', xnew, f6(xnew), 'b-')

# %%
#plt.plot( xnew, f(xnew), '-',label='r=0')
plt.plot(xnew, f2(xnew), '-',label='r=0.1')
plt.plot(xnew, f3(xnew), '-',label='r=0.2')
plt.plot(xnew, f6(xnew), '-',label='r=0.25')

plt.plot(xnew, f4(xnew), '-',label='r=0.3')
plt.plot(xnew, f5(xnew), '-',label='r=0.5')
plt.legend()

# %%
[x2[y2==max(y2)],
x3[y3==max(y3)],
x6[y6==max(y6)],
x4[y4==max(y4)],
x5[y5==max(y5)]]
# Out:
# [array([3.769911]),
#  array([3.769911]),
#  array([4.18879]),
#  array([4.39823]),
#  array([4.39823])]

# %%
x0,y0 = np.loadtxt('vicsek40.txt',delimiter='\t',unpack=True)
f0 = CubicSpline(x0,y0)
xnew = np.linspace(0, 6.0, num=100, endpoint=True)
plt.plot(x0, y0, 'bo', xnew, f0(xnew), 'b-')
